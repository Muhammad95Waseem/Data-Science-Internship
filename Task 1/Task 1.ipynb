# %% [markdown]
# ##  Exploring and Visualizing a Iris Dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_set = pd.read_csv('Iris Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data_set = pd.read_csv('Iris Dataset.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
# ...

# %%
data_set.shape

# %%
data_set.columns

# %%
data_set.head()

# %%
plt.scatter(data_set['SepalLengthCm'], data_set['PetalLengthCm'])
plt.title('Sepal vs. Petal Lenght')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Langht')
plt.show()

# %%
plt.scatter(data_set['SepalWidthCm'], data_set['PetalWidthCm'])
plt.title('Sepal vs. Petal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Petal width')
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.histplot(data=data_set, x='SepalLengthCm', bins=20, color='green')
plt.title('SepalLength Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.histplot(data=data_set, x='PetalLengthCm', bins=20, color='green')
plt.title('PetalLength Distribution')
plt.show()

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(data=data_set, x='SepalLengthCm', color='purple')
plt.title('Spread of Sepal Lenght')

# %%
plt.figure(figsize=(10, 10))
sns.boxplot(data=data_set, x='PetalLengthCm', color='red')
plt.title('Spread of Petal Lenght')
